# %% [markdown]
# # Simple path fix - just add parent directory
# import sys
# import os
# sys.path.append('..')
#
# # Now imports work normally
# from src.utils.db_inventory_manager import DBInventoryManager
# from src.utils.db_transactions_manager import DBTransactionsManager
# import pandas as pd
#
# print("Imports working!")

# %%
import pandas as pd

import sys
import os
sys.path.append('..')

from src.utils.db_inventory_manager import DBInventoryManager
from src.utils.db_transactions_manager import DBTransactionsManager

# %%
inventory_manager = DBInventoryManager()
transactions_manager = DBTransactionsManager()

# %%
# Get all inventory

inventory_query = DBInventoryManager().get_inventory()
inventory_df = pd.DataFrame(inventory_query, columns=['item_id', 'item_name', 'product_type', 'quantity', 'price', 'unit_cost', 'medicine_type', 'expiration_date', 'updated_date'])

# %%
# Get all transaction
transaction = DBTransactionsManager().get_transactions()
transaction_df = pd.DataFrame(transaction, columns=['transaction_id', 'item_name', 'quantity_bought', 'unit_price', 'total_price', 'date_processed', 'transaction_item_id'])

# %% [markdown]
# # Daily sales

# %% [markdown]
# # Products that will expire soon (by 6 months)

# %% [markdown]
# # Products that are running low

# %% [markdown]
# # Top 10 products by sales
